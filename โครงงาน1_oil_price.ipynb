# %% [markdown]
# <a href="https://colab.research.google.com/github/jiriyaporn/data_viz/blob/main/%E0%B9%82%E0%B8%84%E0%B8%A3%E0%B8%87%E0%B8%87%E0%B8%B2%E0%B8%991_oil_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import pandas as pd 
import requests
import re
import datetime as time

# %%
import pandas as pd 
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('https://datahub.io/core/oil-prices/r/wti-daily.csv')
df
# Out:
#             Date  Price
# 0     1986-01-02  25.56
# 1     1986-01-03  26.00
# 2     1986-01-06  26.53
# 3     1986-01-07  25.85
# 4     1986-01-08  25.87
# ...          ...    ...
# 8732  2020-08-25  43.17
# 8733  2020-08-26  43.21
# 8734  2020-08-27  42.88
# 8735  2020-08-28  42.96
# 8736  2020-08-31  42.61
#
# [8737 rows x 2 columns]

# %%
url = 'https://www1.pttor.com/oilprice-capital.aspx'
response = requests.get(url)

# %%
page_html = BeautifulSoup(response.text, 'html.parser')
movie_containers = page_html.find_all('tr', class ="text-center nowrap" )
print(movie_containers)
# Out:
#   File "<ipython-input-42-ccc95d1fbd08>", line 2
#     movie_containers = page_html.find_all('tr', class ="text-center nowrap" )
#                                                     ^
# SyntaxError: invalid syntax

# %%
name = []
years = []
imdb_ratings = []

# %% [markdown]
# ###**oil price**

# %%
pip install zeep

# %%
pip install lxml

# %%
url = "https://www.bangchak.co.th/th/oilprice/historical"
url57 = "https://www.bangchak.co.th/th/oilprice/historical?year=2014"
url1 = "https://www1.pttor.com/oilprice-capital.aspx"

# %%
data = requests.get(url57)
soup = BeautifulSoup(data.text, "html.parser")
valuse = soup.find_all("div",{'class':'container'})
# Out:
# [<div class="container">
# <div class="row">
# <div class="col-12">
# <a class="btn btn--secondary dropdown__btn" href="https://www.bangchak.co.th/th/greenovation/business-overview" target="_self">
# <div class="btn__slide-left">
# <span class="btn__text">ภาพรวมธุรกิจ</span>
# <span class="btn__icon"><i class="fal fa-long-arrow-right"></i></span>
# </div>
# </a>
# </div>
# </div>
# <div class="row">
# <div class="col-12">
# <div class="card-deck card-deck--cards-6">
# <a class="card card--menu " href="https://www.bangchak.co.th/th/greenovation/refinery-business" target="_self">
# <div class="card__figure">
# <img alt="ธุรกิจโรงกลั่นและการค้าน้ำมัน" class="card__image card__zoom-in lazyload" src="https://www.bangchak.co.th/glide/storage/menus/refinery.jpg?w=450&amp;h=296&amp;fm=webp"/>
# </div>
# <div class="card__title">ธุรกิจโรงกลั่นและการค้าน้ำมัน</div>
# </a>
# <a class="card card--menu " href="https://www.bangchak.co.th/th/greenovation/marketing-business" target="_self">
# ...
