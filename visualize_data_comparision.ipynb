# %% [markdown]
# <a href="https://colab.research.google.com/github/jiriyaporn/data_viz/blob/main/visualize_data_comparision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import os

# %%
from datetime import date,datetime

# %%
data = pd.read_csv('/content/search_request.csv')
data
# Out:
#         Unnamed: 0                             search_id  ...        lat        long
# 0                0  683de889-f923-494e-9d46-44a3d67b7259  ...  12.634739  101.463177
# 1                1  4a811230-ffa4-4631-a4c8-5d0394137d02  ...  14.800882  102.533777
# 2                2  7ad6ee8e-438e-4bea-9183-74dcef9e358e  ...  13.738260  100.371405
# 3                3  0c17a5f5-fa89-40f4-ae94-a8659268f827  ...  12.666877  101.860838
# 4                4  6870dc3a-5602-44fc-80ed-df0a7783df9d  ...  12.237242   99.879998
# ...            ...                                   ...  ...        ...         ...
# 180974      180979  07ae983a-fc27-471a-94f2-a13c2525081b  ...  13.826905  100.529945
# 180975      180980  0df3d1d7-9cde-4c86-8790-997112733f45  ...  13.870273  100.593371
# 180976      180981  a017b57e-819e-47f1-bcb1-50f48a241eac  ...  13.840581  100.573540
# 180977      180982  dd953394-e7bf-4db6-b51f-7887b938c9f4  ...  16.432716  102.825300
# ...

# %% [markdown]
# ##เตรียมข้อมูล

# %%
data['search_timestamp']= pd.to_datetime(data['search_timestamp'],dayfirst=True,errors ='coerce') #เปลี่ยนข้อมูลให้เป็นTimsstamp
data
# Out:
#         Unnamed: 0                             search_id  ...        lat        long
# 0                0  683de889-f923-494e-9d46-44a3d67b7259  ...  12.634739  101.463177
# 1                1  4a811230-ffa4-4631-a4c8-5d0394137d02  ...  14.800882  102.533777
# 2                2  7ad6ee8e-438e-4bea-9183-74dcef9e358e  ...  13.738260  100.371405
# 3                3  0c17a5f5-fa89-40f4-ae94-a8659268f827  ...  12.666877  101.860838
# 4                4  6870dc3a-5602-44fc-80ed-df0a7783df9d  ...  12.237242   99.879998
# ...            ...                                   ...  ...        ...         ...
# 180974      180979  07ae983a-fc27-471a-94f2-a13c2525081b  ...  13.826905  100.529945
# 180975      180980  0df3d1d7-9cde-4c86-8790-997112733f45  ...  13.870273  100.593371
# 180976      180981  a017b57e-819e-47f1-bcb1-50f48a241eac  ...  13.840581  100.573540
# 180977      180982  dd953394-e7bf-4db6-b51f-7887b938c9f4  ...  16.432716  102.825300
# ...

# %% [markdown]
# ##Bar-chart

# %%
data["search_timestamp"] = pd.to_datetime(data["search_timestamp"])
data
# Out:
#         Unnamed: 0                             search_id  ...        lat        long
# 0                0  683de889-f923-494e-9d46-44a3d67b7259  ...  12.634739  101.463177
# 1                1  4a811230-ffa4-4631-a4c8-5d0394137d02  ...  14.800882  102.533777
# 2                2  7ad6ee8e-438e-4bea-9183-74dcef9e358e  ...  13.738260  100.371405
# 3                3  0c17a5f5-fa89-40f4-ae94-a8659268f827  ...  12.666877  101.860838
# 4                4  6870dc3a-5602-44fc-80ed-df0a7783df9d  ...  12.237242   99.879998
# ...            ...                                   ...  ...        ...         ...
# 180974      180979  07ae983a-fc27-471a-94f2-a13c2525081b  ...  13.826905  100.529945
# 180975      180980  0df3d1d7-9cde-4c86-8790-997112733f45  ...  13.870273  100.593371
# 180976      180981  a017b57e-819e-47f1-bcb1-50f48a241eac  ...  13.840581  100.573540
# 180977      180982  dd953394-e7bf-4db6-b51f-7887b938c9f4  ...  16.432716  102.825300
# ...

# %% [markdown]
# ###Quiz6

# %%
top_table = data.iloc[:10,:]
top_table
# Out:
#    Unnamed: 0                             search_id  ...        lat        long
# 0           0  683de889-f923-494e-9d46-44a3d67b7259  ...  12.634739  101.463177
# 1           1  4a811230-ffa4-4631-a4c8-5d0394137d02  ...  14.800882  102.533777
# 2           2  7ad6ee8e-438e-4bea-9183-74dcef9e358e  ...  13.738260  100.371405
# 3           3  0c17a5f5-fa89-40f4-ae94-a8659268f827  ...  12.666877  101.860838
# 4           4  6870dc3a-5602-44fc-80ed-df0a7783df9d  ...  12.237242   99.879998
# 5           5  4c048ac7-9fc7-49e8-9ee4-20ff755b939d  ...  12.853119  101.108515
# 6           6  3ecf13ba-be4d-4eb9-9374-a1cca09d1614  ...  12.451104  102.248522
# 7           7  a7e6b7c5-3d3c-4337-8337-d29c5346b686  ...  13.640855  100.433287
# 8           8  02fedb5c-c9cd-46d7-9354-7613ecb7cfdd  ...  13.720904  100.527299
# 9           9  e215d487-0450-4794-830a-ecfc0ab6493b  ...  13.720835  100.527152
#
# [10 rows x 10 columns]

# %%
top_table[top_table['search_timestamp'].dt.dayofweek == 3]
# Out:
#    Unnamed: 0                             search_id  ...        lat        long
# 0           0  683de889-f923-494e-9d46-44a3d67b7259  ...  12.634739  101.463177
# 1           1  4a811230-ffa4-4631-a4c8-5d0394137d02  ...  14.800882  102.533777
# 2           2  7ad6ee8e-438e-4bea-9183-74dcef9e358e  ...  13.738260  100.371405
#
# [3 rows x 10 columns]

# %%
top_table[top_table['search_timestamp'].dt.dayofweek == 4]
# Out:
#    Unnamed: 0                             search_id  ...        lat        long
# 5           5  4c048ac7-9fc7-49e8-9ee4-20ff755b939d  ...  12.853119  101.108515
# 6           6  3ecf13ba-be4d-4eb9-9374-a1cca09d1614  ...  12.451104  102.248522
# 7           7  a7e6b7c5-3d3c-4337-8337-d29c5346b686  ...  13.640855  100.433287
# 8           8  02fedb5c-c9cd-46d7-9354-7613ecb7cfdd  ...  13.720904  100.527299
# 9           9  e215d487-0450-4794-830a-ecfc0ab6493b  ...  13.720835  100.527152
#
# [5 rows x 10 columns]

# %%
top_table[top_table['search_timestamp'].dt.dayofweek == 5]
# Out:
#    Unnamed: 0                             search_id  ...        lat        long
# 3           3  0c17a5f5-fa89-40f4-ae94-a8659268f827  ...  12.666877  101.860838
# 4           4  6870dc3a-5602-44fc-80ed-df0a7783df9d  ...  12.237242   99.879998
#
# [2 rows x 10 columns]

# %%
plt.bar([1,2,3,4,5,6,7],[data[data['search_timestamp']]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-cfc8d9e34e29> in <module>()
# ----> 1 plt.bar([1,2,3,4,5,6,7],[data[data['search_timestamp']]])
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ##Quiz

# %% [markdown]
# https://medium.com/@kanyawee.work/%E0%B9%81%E0%B8%AA%E0%B8%94%E0%B8%87%E0%B8%9C%E0%B8%A5%E0%B8%A0%E0%B8%B2%E0%B8%A9%E0%B8%B2%E0%B9%84%E0%B8%97%E0%B8%A2%E0%B9%83%E0%B8%99%E0%B8%81%E0%B8%A3%E0%B8%B2%E0%B8%9F%E0%B8%82%E0%B8%AD%E0%B8%87-matplotlib-%E0%B8%9A%E0%B8%99-google-colab-37210d9a9f31

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
import matplotlib.pyplot as plt

# %%
mon = data[data['search_timestamp'].dt.dayofweek == 0].shape[0]
tue = data[data['search_timestamp'].dt.dayofweek == 1].shape[0]
wed = data[data['search_timestamp'].dt.dayofweek == 2].shape[0]
thu = data[data['search_timestamp'].dt.dayofweek == 3].shape[0]
fri = data[data['search_timestamp'].dt.dayofweek == 4].shape[0]
sat = data[data['search_timestamp'].dt.dayofweek == 5].shape[0]
sun = data[data['search_timestamp'].dt.dayofweek == 6].shape[0]

# %%
plt.bar([1,2,3,4,5,6,7], [mon, tue, wed, thu, fri, sat, sun], tick_label = ['Mon','Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
plt.xlabel('Day')
plt.ylabel('Number of Reques')
plt.title('จำนวนคนเข้าเว็บวงในแต่ละวัน');

# %% [markdown]
# แสดงปริมาณคนเข้าเว้บวงในในเเต่ละวันโดยเปรียบเทียบแต่ละวัน 11.00-12.00 กับ 23.00-24.00

# %%
sun & ( data['search_timestamp'.dt.time < time(hour==12)
& (data['seach_timestamp'].dt.time >= time(hour==11))].shape[0]
# Out:
#   File "<ipython-input-29-cf990923caeb>", line 2
#     & (data['seach_timestamp'].dt.time >= time(hour==11))].shape[0]
#                                                                    ^
# SyntaxError: unexpected EOF while parsing

# %%
data[data['search_timestamp'].dt.dayofweek == 0] & (data['search_timestamp'.dt.time < time(hour==12).shape[0]
data[data['search_timestamp'].dt.dayofweek == 0] & (data['search_timestamp'.dt.time < time(hour==12).shape[0]
data[data['search_timestamp'].dt.dayofweek == 0] & (data['search_timestamp'.dt.time < time(hour==12).shape[0] 
data[data['search_timestamp'].dt.dayofweek == 0] & (data['search_timestamp'.dt.time < time(hour==12).shape[0]
data[data['search_timestamp'].dt.dayofweek == 0] & (data['search_timestamp'.dt.time < time(hour==12).shape[0]
