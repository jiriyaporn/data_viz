# %% [markdown]
# <a href="https://colab.research.google.com/github/jiriyaporn/data_viz/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
path = '/content/drive/My Drive/dataviz'

# %%
income_file_path = os.path.join(path, 'income.csv')
print(income_file_path)
# Out:
# /content/drive/My Drive/dataviz/income.csv

# %%
a = path + '/income.csv'
print(a)
# Out:
# /content/drive/My Drive/dataviz/income.csv

# %%
aa = pd.read_csv(income_file_path)
aa
# Out:
#     ???????????????????????????????? ??????????? ?????????? ?.?. 2541 - 2558  ... Unnamed: 66
# 0    Average Monthly Income Per Household: 1998 - 2015                        ...         NaN
# 1                                                  NaN                        ...         NaN
# 2                                       ??? ??????????                        ...         NaN
# 3                                                  NaN                        ...         NaN
# 4                                                  NaN                        ...         NaN
# ..                                                 ...                        ...         ...
# 104                                                NaN                        ...         NaN
# 105                                                NaN                        ...         NaN
# 106                                                NaN                        ...         NaN
# ...
